# %% [markdown]
# To begin upload this notebook to your own drive:
#
# ### Submission Instructions:
# 1. **Restart the kernel** (in the menubar, select Runtime$\rightarrow$Restart runtime)
# 2. **Run all cells** (in the menubar, select Runtime$\rightarrow$Run All).
# 3. **Download the notebook** (in the menubar, select File$\rightarrow$Download .ipynb)
# 4. **Upload the downloaded notebook (.ipynb file) to your repository**.
#
# Note: To use a GPU, do the following: Runtime$\rightarrow$Change runtime type$\rightarrow$ GPU
#
# Make sure you fill in any place that says `YOUR CODE HERE`, and that no tests fail.

# %% [markdown]
# # ![shakespeare](https://i.imgur.com/81YZuel.jpg)
#
# # Generating Shakespeare Using a Character-level Language Model
#
# ### From Words to Characters
# In the previous section we dealt with word-level language models. But looking again at section 1, there is nothing that constraints us to using _words_ as the basic elemnents in our model. The model we analyzed in section 1 could just as well be character-based - just replace "word" with "character", and you are good to go. In this notebook we will train a small character-based language model that will help us generate Shakespearean-like (emphasis on the _like_...) texts.

# %% [markdown]
# ### Question 2.a
# Can you think of an advantage a character-based language model could have over a word-based language model? And what about the other way around: can you think of an advantage a word-based language model could have over a character-based language model? (Add your answer to the final submission pdf).

# %% [markdown]
# ### Using PyTorch
#
# We'll build our language model using PyTorch. PyTorch is a [very popular](https://thegradient.pub/state-of-ml-frameworks-2019-pytorch-dominates-research-tensorflow-dominates-industry/) open-source machine learning (and deep learning) framework developed by Facebook. In short:
#
# > Pytorch is a Python-based scientific computing package targeted at two sets of audiences:
# * A replacement for NumPy to use the power of GPUs
# * A deep learning research platform that provides maximum flexibility and speed
#
# To get familiar with PyTorch, check out this [quick tutorial](https://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html). In addition, another imporant difference from numpy is that PyTorch can automatically calculate the gradients needed for backpropagation, as explained [here](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html).

# %% [markdown]
# ### Preparing the Data
#
# Our dataset is a plain text file. For simplicity, we turn any potential unicode characters into plain ASCII by using the `unidecode` package.

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.12/dist-packages (1.4.0)

# %%
import string
import random
import re
import requests
import unidecode
url = "https://github.com/tau-nlp-course/NLP_HW2/raw/main/data/shakespeare.txt"


all_characters = string.printable
n_characters = len(all_characters)  # our vocabulary size (|V| from the handout)

dataset_as_string = unidecode.unidecode(requests.get(url).content.decode())
n_chars_in_dataset = len(dataset_as_string)
print(f'Total number of characters in our dataset: {n_chars_in_dataset}')
# Out:
# Total number of characters in our dataset: 1115394

# %% [markdown]
# To make inputs out of this big string of text, we will split it into chunks.

# %%
chunk_len = 400

def random_chunk():
    start_index = random.randint(0, n_chars_in_dataset - chunk_len)
    end_index = start_index + chunk_len + 1
    return dataset_as_string[start_index:end_index]

print(random_chunk())
# Out:
# d for the liberal arts
# Without a parallel; those being all my study,
# The government I cast upon my brother
# And to my state grew stranger, being transported
# And rapt in secret studies. Thy false uncle--
# Dost thou attend me?
#
# MIRANDA:
# Sir, most heedfully.
#
# PROSPERO:
# Being once perfected how to grant suits,
# How to deny them, who to advance and who
# To trash for over-topping, new created
# The creatures t

# %% [markdown]
# ### Building Our Model
#
# Our model consists of three main components:
#
# 1. [**Embedding**](https://pytorch.org/docs/stable/nn.html#embedding). A mapping between characters and their learned representations ("word vectors") \[correspoding to ${\boldsymbol L}$ in terms of the handout\]
# 2. [**GRU**](https://pytorch.org/docs/stable/nn.html#gru). \[correspoding to the computation of ${\boldsymbol h}^{(t)}$ in terms of the handout\]
# 3. **Output Layer**. A feed-forward neural network that transforms a hidden state at a timestep into a probability distribution of the next character. \[correspoding to the computation of $\hat{\boldsymbol y}^{(t)}$ in terms of the handout\]

# %% [markdown]
# ### Question 2.b
# Complete the implementation of the `forward` method of our model.

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

class OurModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(OurModel, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, hidden_size)  # In the terms of the handout, here d = D_h
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers)
        self.output_layer = nn.Linear(hidden_size, output_size)

    def forward(self, input_, hidden):
        # General instructions:
        # Pass the embedded input through the GRU and use the output layer to get the next character logits.
        # return that logits and the next hidden state.
        # You may need to play around with the dimensions a bit until you get it right. Dimension-induced frustration is good for you!
        # -------------------------
        # YOUR CODE HERE
        embedded_input = self.embedding(input_).view(1, 1, -1)
        output, hidden = self.gru(embedded_input, hidden)
        output = self.output_layer(output.view(1, -1))
        # -------------------------
        return output, hidden

    def init_hidden(self):
        return Variable(torch.zeros(self.num_layers, 1, self.hidden_size))

# %% [markdown]
# ### Creating the Training Examples

# %% [markdown]
# Each chunk will be turned into a tensor by looping through the characters of the string and looking up the index of each character in `all_characters`.

# %%
# Turn a string into list of longs
def chars_to_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor)

print(chars_to_tensor('abcDEF'))
# Out:
# tensor([10, 11, 12, 39, 40, 41])

# %% [markdown]
# Now we can assemble a pair of input and target tensors (i.e. a single training example) for training, from a random chunk. The input will be all characters *except the last*, and the target will be all characters *except the first*. So if our chunk is "abc" the input will correspond to "ab" while the target is "bc".

# %%
def random_training_set():
    chunk = random_chunk()
    inp = chars_to_tensor(chunk[:-1])
    target = chars_to_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# ### Evaluating
#
# To evaluate the network we will feed one character at a time, use the outputs of the network as a probability distribution for the next character, and repeat. To start generation we pass a priming string to start building up the hidden state, from which we then generate one character at a time.

# %%
import torch.nn.functional as F

def evaluate(prime_str='A', predict_len=100, temperature=0.8):
    hidden = model.init_hidden()
    prime_input = chars_to_tensor(prime_str)
    predicted = prime_str

    # Use priming string to "build up" hidden state
    for p in range(len(prime_str) - 1):
        _, hidden = model(prime_input[p], hidden)
    inp = prime_input[-1]

    for p in range(predict_len):
        output, hidden = model(inp, hidden)

        # Sample from the network as a multinomial distribution
        output_dist =  F.softmax(output / temperature, dim=-1)
        top_i = torch.multinomial(output_dist, 1)[0]

        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = chars_to_tensor(predicted_char)

    return predicted

# %% [markdown]
# ### Training

# %% [markdown]
# The main training function

# %%
def train(inp, target):
    hidden = model.init_hidden()
    model.zero_grad()
    loss = 0

    for c in range(chunk_len):
        output, hidden = model(inp[c], hidden)
        loss += criterion(output, target[c].view(-1))

    loss.backward()
    optimizer.step()

    return loss.item() / chunk_len

# %% [markdown]
# A helper to print the amount of time passed:

# %%
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return f'{m}m {math.floor(s)}s'

# %%
# DO NOT DELETE THIS CELL

# %% [markdown]
# Define the training parameters, instantiate the model, and start training:

# %%
n_epochs = 2000
print_every = 100
plot_every = 10
hidden_size = 100  # (D_h from the handout)
num_layers = 1
lr = 0.005

model = OurModel(n_characters, hidden_size, n_characters, num_layers)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())
    loss_avg += loss

    if epoch % print_every == 0:
        print(f'[time elapsed: {time_since(start)}  ;  epochs: {epoch} ({epoch / n_epochs * 100}%)  ;  loss: {loss:.4}]')
        print(evaluate('Wh', 200), '\n')  # generate text starting with 'Wh'

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
# [time elapsed: 0m 34s  ;  epochs: 100 (5.0%)  ;  loss: 2.281]
# Whadd ar lot hird ann thamons force oom non the the is rean
# Theac in mabicerve's! araye o yon that my thighe am sideacess may shis it haust chidy hing,
# Herent be gy wing Boure lome ghire heat toun and s
#
# [time elapsed: 1m 9s  ;  epochs: 200 (10.0%)  ;  loss: 2.082]
# Which not be, dodaice
# But in is bours 'four douphat fear ang; Wardurst thy be of wooshincond'll to.
#
# Nonou a that the fetour nourd's heaj be reathpe and your oull ange.
#
# QUEN INCEN EDT:
# I hath ustene, n
#
# [time elapsed: 1m 41s  ;  epochs: 300 (15.0%)  ;  loss: 2.001]
# Whis with of therainot a wall it will to your you pate.
#
# Cettirnencest there dost, the the to griest I pentad doofwath'r
# And yould befor by to getwid for daost?
#
# GoMARRD VILARLA:
# Whe non you doours the
#
# [time elapsed: 2m 16s  ;  epochs: 400 (20.0%)  ;  loss: 1.801]
# Whick hom himsed man seeding is whis say serdy!
# He siry tome of thearry
# Thy fare it in the min:
# Her here ind there comes as he well, Bety liver them seft's the
# Whit, and hep my grown of thee nursed.
#
# GR
#
# [time elapsed: 2m 49s  ;  epochs: 500 (25.0%)  ;  loss: 2.172]
# Whsight! of the come,
# you le doid sery a senst me to in their coonded ther re not a doen to beir theren to moud have vies endpidon ther sard over dif
# Came they hoand a the sper, hustens ur to fart,
# My w
#
# [time elapsed: 3m 22s  ;  epochs: 600 (30.0%)  ;  loss: 1.634]
# What
# Thou ham al to hererieg.
#
# HUCHENTES:
# Good Mards canming tuppert the but comesh in to age.
#
# STENSBO:
# You be she coom it colly.
# 'ON EWARD II RICIS:
# My bour me
# thy neseed mince whinted with hing one,
#
#
# [time elapsed: 3m 55s  ;  epochs: 700 (35.0%)  ;  loss: 1.815]
# Whip, men him, seet of my
# Iad I scall them
# Prick sunys of then her and say ampy lork
# What the precize, pray our theren
# show law it commmannessings end them she shall your hus?
# Thim whint me supt inthem
#
# [time elapsed: 4m 26s  ;  epochs: 800 (40.0%)  ;  loss: 1.8]
# Why ever shall that I all not with for
# And the kead the semy abless peronins, starach now see me,
# When those unserving you hose taly her sene much they,
# A grove the ever youse Must ever which quars a st
#
# [time elapsed: 4m 58s  ;  epochs: 900 (45.0%)  ;  loss: 1.781]
# Whiffon and that devive on bust,
# I nother as
# the abood the the dieve distort.
#
# GLOUCOSES:
# My porace is of trown his say thee adling.
#
# LADY dICHARD:
# And be you mellod the dow
# To the soly you will scark t
#
# [time elapsed: 5m 30s  ;  epochs: 1000 (50.0%)  ;  loss: 1.707]
# Whosty core.
# Your cour in that frother a world not charderel, sirne chart:
# A with the reasosed's in sirgars,
# Yet agais, so lowfull lown both; your mourn he a conder.
#
# AULINGBRZORD:
# A bid to her the inti
#
# [time elapsed: 6m 2s  ;  epochs: 1100 (55.00000000000001%)  ;  loss: 1.646]
# Wherver,
# Thou man, shame, my are a came you, forth, mound.
# The speak all roke to-more the and sir, that that thee chell-forthour proovely;
# Thyself for call my love. Mord, I shall came of our strick,
# Not
#
# [time elapsed: 6m 33s  ;  epochs: 1200 (60.0%)  ;  loss: 1.691]
# Whicle benectuent!
#
# LADY ANNE:
# The may hard the are you have Mard beward to dight not hands.
#
# LADY GLOULINA:
# My worm tho here beate himes all and them decamence;
# I would lets that ware, and livenged wil
#
# [time elapsed: 7m 5s  ;  epochs: 1300 (65.0%)  ;  loss: 1.674]
# Wharge there offace;
# Forch practrown to suer, to undel'd
# Take and you song and fertion;
# Be to your lord! Proves, I'll done.
#
# BIOND:
#
# BERCUTHE:
# My bold your shall your longh
# Rome pery, seord, prizenst a
#
# [time elapsed: 7m 37s  ;  epochs: 1400 (70.0%)  ;  loss: 1.882]
# Which good grace, men in may;
# And not presiatice I come lover; the couse and when as we son-forged bey holshed;
# As contread our she elvent; eder; but thou leave, and stried furdestanciaty.
#
# LEONTER:
# The
#
# [time elapsed: 8m 9s  ;  epochs: 1500 (75.0%)  ;  loss: 1.756]
# Whatt, I crown.
#
# RICHARD:
# The clood of day!
# All gentlest sight man swelf the scoe in mine blessed:
# Cas make you do steased your draw,
# To come to have lord, of to lo ligece.
#
# RORTIO:
# So for the brew'sted
#
# [time elapsed: 8m 42s  ;  epochs: 1600 (80.0%)  ;  loss: 1.758]
# WhIn that in falf,
# And for the at hip hure am they house un.
#
# DUKE VINCENTIO:
# Your he nevers; sice,
# Fight the infay in see a men do our
# And thou, preep in hath not give in her had
# Where the dand do the
#
# [time elapsed: 9m 17s  ;  epochs: 1700 (85.0%)  ;  loss: 2.201]
# Wharthing is,
# Your kinging the cronger.
#
# COMIO:
# Not he well that who and the pringes ampury 'ot and a hear.
# O, I long, they stayd to shroce, the one,
# But a for well at thine still nok one now
# To the mor
#
# [time elapsed: 9m 52s  ;  epochs: 1800 (90.0%)  ;  loss: 1.984]
# What not the retindred
# son it I hich Ay?
#
# LADY GREY:
# I well to art stay's being thee is eoppience.
#
# MENENENIUS:
# I mean, service, are a rechined, not loys, and
# this mate imple of asse't
# To think, the sta
#
# [time elapsed: 10m 25s  ;  epochs: 1900 (95.0%)  ;  loss: 1.36]
# Which the now:
# I may nown try but more that
# That ammonds har till my ghigut:
# Go quitious hath weapience, this craughter,
# He shall this fortey warried as do these
# Thou nowinter as so, hare it is, or know
#
# [time elapsed: 10m 57s  ;  epochs: 2000 (100.0%)  ;  loss: 1.671]
# While to thou trucked the but faciucters
# I mirness unto man so lovest thend meignt; hoouselfinours, anlans:
# I shougue; father so be death deet the do deerting to pray;
# And the prouds to theng. What thee

# %% [markdown]
# ### Training Loss
#
# Plotting the the losses that were computed during training can provide a further indication that the network was indeed learning (Add your plot to the final submission pdf).

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.grid(True)
plt.xlabel('# of epochs (divided by plot_every)')
plt.ylabel('average loss')
plt.plot(all_losses)

# %%
# Q3(b): Perplexity of the trained char-RNN on Wikipedia and Shakespeare passages.
  # Assumes `model`, `all_characters`, `chars_to_tensor` are already in scope from earlier cells.

import requests
import unidecode
import math
import torch.nn.functional as F
WIKI_URL = "https://github.com/tau-nlp-course/NLP_HW2/raw/main/data/wikipedia_for_perplexity.txt"
SHAKESPEARE_URL = "https://github.com/tau-nlp-course/NLP_HW2/raw/main/data/shakespeare_for_perplexity.txt"


def load_passage(url):
    raw = requests.get(url).content.decode()
    cleaned = unidecode.unidecode(raw)
    return "".join(c for c in cleaned if c in all_characters)


def char_perplexity(text):
    model.eval()
    inp = chars_to_tensor(text[:-1])
    target = chars_to_tensor(text[1:])
    hidden = model.init_hidden()
    total_log_prob = 0.0
    with torch.no_grad():
        for c in range(len(inp)):
            output, hidden = model(inp[c], hidden)
            log_probs = F.log_softmax(output, dim=-1)
            total_log_prob += log_probs[0, target[c].item()].item()
    avg_neg_log_prob = -total_log_prob / len(inp)
    return math.exp(avg_neg_log_prob)


wiki_text = load_passage(WIKI_URL)
shake_text = load_passage(SHAKESPEARE_URL)

print(f"Wikipedia perplexity:   {char_perplexity(wiki_text):.4f}")
print(f"Shakespeare perplexity: {char_perplexity(shake_text):.4f}")
# Out:
# Wikipedia perplexity:   2253.5509
# Shakespeare perplexity: 2252.1630
